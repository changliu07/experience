# %% [markdown]
# # Notes for 28 September
#
# Today we'll do more with images

# %%
# %matplotlib inline
import numpy as np
import pylab

# %% [markdown]
# First let's grab an image of Frederick Phillips Brooks.

# %%
import urllib
urllib.request.urlretrieve('https://goo.gl/9c5MHC', filename='fpb.jpg')
# Out:
# ('fpb.jpg', <http.client.HTTPMessage at 0x7f8c7b33d668>)

# %% [markdown]
# Then we can read it with a function from pylab. The image is a 3D array. (rows, columns, channels)

# %%
fpb = pylab.imread('fpb.jpg')
print(fpb.shape)
# Out:
# (165, 305, 3)

# %% [markdown]
# And we can display it with our usual helper.

# %%
def show(im):
    pylab.imshow(im, cmap=pylab.gray(), interpolation='none')
    
show(fpb)

# %% [markdown]
# We can pull out the red channel.

# %%
show(fpb[:, :, 0])

# %% [markdown]
# The green channel.

# %%
show(fpb[:, :, 1])

# %% [markdown]
# The **pixels** are just numbers. Below I display the green channel of the first column.

# %%
fpb[:, 0, 1]
# Out:
# array([218, 218, 218, 218, 218, 218, 218, 218, 218, 218, 218, 218, 218,
#        218, 218, 218, 218, 218, 218, 218, 218, 218, 218, 218, 220, 220,
#        220, 220, 220, 220, 220, 220, 219, 219, 219, 219, 219, 219, 219,
#        219, 221, 221, 221, 221, 221, 221, 221, 221, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 221, 221, 221, 221, 221, 221,
#        221, 221, 222, 222, 222, 222, 222, 222, 222, 222, 222, 222, 222,
#        222, 222, 222, 222, 222, 222, 222, 222, 222, 222, 222, 222, 222,
#        223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223,
#        223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 223, 226, 225,
#        225, 225, 224, 224, 223, 223, 217, 217, 217, 217, 217, 217, 217,
#        217, 219, 219, 219, 219, 219, 219, 219, 219, 220, 220, 220, 220,
#        220, 220, 220, 220, 220, 220, 220, 220, 220], dtype=uint8)

# %% [markdown]
# We can convert the RGB image to luminance with an approximation of the weight of each channel.

# %%
lum = 0.2 * fpb[:, :, 0] + 0.7 * fpb[:, :, 1] + 0.1 * fpb[:, :, 2]
show(lum)

# %% [markdown]
# We can get the max luminance.

# %%
np.max(lum)
# Out:
# 250.59999999999999

# %% [markdown]
# And the min.

# %%
np.min(lum)
# Out:
# 1.4000000000000001

# %% [markdown]
# We can convert it to a binary image by thresholding it.

# %%
show(lum > 128)

# %% [markdown]
# Choosing different thresholds washes out different parts of the image.

# %%
show(lum > 50)

# %%
show(lum > 200)

# %%
np.min(lum)
# Out:
# 1.4000000000000001

# %% [markdown]
# We can rescale the luminance to be between 0 and 1 by subtracting off the min and dividing by the max.

# %%
lum = lum - np.min(lum)
lum = lum / np.max(lum)
show(lum)

# %% [markdown]
# Here is a row through the image.

# %%
lum[85, :]
# Out:
# array([ 0.87319422,  0.87720706,  0.8812199 ,  0.88523274,  0.88924559,
#         0.89325843,  0.89727127,  0.89727127,  0.89727127,  0.89727127,
#         0.89727127,  0.90128411,  0.90128411,  0.90128411,  0.90529695,
#         0.90529695,  0.91131621,  0.90329053,  0.90329053,  0.90730337,
#         0.90850722,  0.88844302,  0.84831461,  0.81219904,  0.83547352,
#         0.83547352,  0.83547352,  0.83547352,  0.83667737,  0.83667737,
#         0.83667737,  0.8382825 ,  0.83226324,  0.83266453,  0.83988764,
#         0.84149278,  0.820626  ,  0.605939  ,  0.31861958,  0.29253612,
#         0.26725522,  0.36918138,  0.29815409,  0.12800963,  0.11035313,
#         0.2094703 ,  0.26364366,  0.26083467,  0.27849117,  0.29494382,
#         0.2676565 ,  0.27207063,  0.30738363,  0.25481541,  0.1565008 ,
#         0.11717496,  0.15288925,  0.27287319,  0.35313002,  0.42696629,
#         0.54093098,  0.56260032,  0.50601926,  0.48154093,  0.50441413,
#         0.43619583,  0.25361156,  0.25200642,  0.30617978,  0.3182183 ,
#         0.3282504 ,  0.39767255,  0.52929374,  0.58507223,  0.5758427 ,
#         0.61316212,  0.73836276,  0.78089888,  0.77166934,  0.8358748 ,
#         0.84430177,  0.84711075,  0.855939  ,  0.85955056,  0.85272873,
#         0.84871589,  0.84069021,  0.83306581,  0.57022472,  0.820626  ,
#         0.95184591,  0.97030498,  0.79855538,  0.48956661,  0.48394864,
#         0.47070626,  0.51444623,  0.55898876,  0.56942215,  0.65248796,
#         0.56741573,  0.53370787,  0.54494382,  0.62961477,  0.70184591,
#         0.67776886,  0.51364366,  0.40008026,  0.58547352,  0.6135634 ,
#         0.61195827,  0.56420546,  0.61075441,  0.70505618,  0.68900482,
#         0.65168539,  0.69382022,  0.69783307,  0.72191011,  0.71508828,
#         0.56540931,  0.57664526,  0.58868379,  0.60393258,  0.62319422,
#         0.64446228,  0.66934189,  0.68739968,  0.74799358,  0.76163724,
#         0.74317817,  0.77568218,  0.69502408,  0.65730337,  0.55457464,
#         0.59711075,  0.72953451,  0.75160514,  0.77367576,  0.76886035,
#         0.74518459,  0.72271268,  0.72150883,  0.72552167,  0.73314607,
#         0.74157303,  0.74839486,  0.7524077 ,  0.73314607,  0.70505618,
#         0.67375602,  0.65449438,  0.59711075,  0.57704655,  0.54173355,
#         0.48956661,  0.41934189,  0.3358748 ,  0.25963082,  0.20666132,
#         0.20505618,  0.27889246,  0.27889246,  0.31219904,  0.45626003,
#         0.52367576,  0.45184591,  0.39566613,  0.28932584,  0.34670947,
#         0.43980738,  0.52808989,  0.58065811,  0.59269663,  0.60072231,
#         0.61195827,  0.59751204,  0.59069021,  0.58868379,  0.58667737,
#         0.58065811,  0.57985554,  0.5782504 ,  0.5782504 ,  0.55738363,
#         0.57263242,  0.57463884,  0.56661316,  0.54253612,  0.52487961,
#         0.53491172,  0.5453451 ,  0.53932584,  0.51565008,  0.53370787,
#         0.6035313 ,  0.63202247,  0.59871589,  0.78130016,  0.84991974,
#         0.87961477,  0.78009631,  0.23073836,  0.06741573,  0.0959069 ,
#         0.0934992 ,  0.13523274,  0.12520064,  0.09109149,  0.06099518,
#         0.0529695 ,  0.18418941,  0.28250401,  0.41773676,  0.54935795,
#         0.40208668,  0.40088283,  0.38322632,  0.29373997,  0.09149278,
#         0.09189406,  0.27287319,  0.31260032,  0.29454254,  0.37078652,
#         0.37199037,  0.43900482,  0.40770465,  0.24117175,  0.22833066,
#         0.17576244,  0.11677368,  0.21268058,  0.21990369,  0.24277689,
#         0.33467095,  0.59630819,  0.62921348,  0.52046549,  0.73434992,
#         0.90609952,  0.91131621,  0.91051364,  0.91452648,  0.91613162,
#         0.91733547,  0.91853933,  0.91573034,  0.8964687 ,  0.88443018,
#         0.90008026,  0.92375602,  0.62078652,  0.51926164,  0.50280899,
#         0.56260032,  0.58788122,  0.61235955,  0.62239165,  0.7070626 ,
#         0.6918138 ,  0.57784912,  0.45425361,  0.82945425,  0.91211878,
#         0.91131621,  0.91011236,  0.90930979,  0.9117175 ,  0.9117175 ,
#         0.91091493,  0.9117175 ,  0.89767255,  0.89807384,  0.89807384,
#         0.90208668,  0.90088283,  0.90048154,  0.90449438,  0.90569823,
#         0.91332263,  0.86637239,  0.80377207,  0.77287319,  0.78571429,
#         0.81902087,  0.85072231,  0.86316212,  0.88322632,  0.89085072,
#         0.8988764 ,  0.77889246,  0.85714286,  0.88603531,  0.21829856,
#         0.08226324,  0.09871589,  0.05577849,  0.08346709,  0.02889246,
#         0.48515249,  0.9418138 ,  0.95024077,  0.9394061 ,  0.94863563])

# %% [markdown]
# We can plot that line of intensities.

# %%
pylab.plot(lum[85, :])

# %% [markdown]
# We could make an image from random numbers.

# %%
show(np.random.random(lum.shape))

# %%
lum.shape
# Out:
# (165, 305)

# %% [markdown]
# We talked about down sampling the image.

# %%
show(lum[::2, ::2])

# %%
show(lum[::8, ::8])

# %% [markdown]
# Let's go back to our binary image.

# %%
show(lum > 0.5)

# %% [markdown]
# Let's threshold it with some added noise. Notice that we get a better approximation to the original image by adding noise to reveal some of the shades of gray

# %%
noise = 2 * np.random.random(lum.shape) - 1
show(lum + 0.1 * noise > 0.5)

# %% [markdown]
# More noise gives us more shades of gray but makes for a noisier picture.

# %%
show(lum + 0.2 * noise > 0.5)
